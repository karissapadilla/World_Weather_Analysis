# %%
# Import databases.
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fbac3b1841bb72f0f16e93559920022e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kieta
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | hirara
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | saint anthony
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | malkara
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | morant bay
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | fuling
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | severnoye
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | tuy hoa
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 1 | marica
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | trumbull
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | port hedland
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | vila velha
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | tacuati
# Processing Record 39 of Set 1 | iberia
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | huarmey
# Processing Record 44 of Set 1 | zvishavane
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | lorengau
# Processing Record 1 of Set 2 | buala
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | diego de almagro
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | ahipara
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | turukhansk
# Processing Record 10 of Set 2 | muli
# Processing Record 11 of Set 2 | kahului
# Processing Record 12 of Set 2 | oussouye
# Processing Record 13 of Set 2 | saint-pierre
# Processing Record 14 of Set 2 | harper
# Processing Record 15 of Set 2 | lagoa
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | mahajanga
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | marapanim
# Processing Record 22 of Set 2 | chapayevka
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | zhigansk
# Processing Record 26 of Set 2 | tual
# Processing Record 27 of Set 2 | palasa
# Processing Record 28 of Set 2 | krabi
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | iseyin
# Processing Record 31 of Set 2 | yar-sale
# Processing Record 32 of Set 2 | gamba
# Processing Record 33 of Set 2 | katangli
# Processing Record 34 of Set 2 | yeniseysk
# Processing Record 35 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | sayyan
# Processing Record 38 of Set 2 | gimli
# Processing Record 39 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | gouloure
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | calbuco
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | lata
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | salalah
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 9 of Set 3 | baykit
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | waipawa
# Processing Record 12 of Set 3 | watertown
# Processing Record 13 of Set 3 | fort morgan
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | san felipe
# Processing Record 16 of Set 3 | muscat
# Processing Record 17 of Set 3 | lichinga
# Processing Record 18 of Set 3 | half moon bay
# Processing Record 19 of Set 3 | novyy urengoy
# Processing Record 20 of Set 3 | port moresby
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | velikooktyabrskiy
# Processing Record 23 of Set 3 | kudahuvadhoo
# Processing Record 24 of Set 3 | luena
# Processing Record 25 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | ndele
# Processing Record 29 of Set 3 | acarau
# Processing Record 30 of Set 3 | san policarpo
# Processing Record 31 of Set 3 | pangai
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | hlobyne
# Processing Record 34 of Set 3 | evensk
# Processing Record 35 of Set 3 | lewiston
# Processing Record 36 of Set 3 | sorsk
# Processing Record 37 of Set 3 | high wycombe
# Processing Record 38 of Set 3 | bilibino
# Processing Record 39 of Set 3 | loanda
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | khakhea
# Processing Record 45 of Set 3 | eureka
# Processing Record 46 of Set 3 | lake city
# Processing Record 47 of Set 3 | ginir
# Processing Record 48 of Set 3 | dalby
# Processing Record 49 of Set 3 | barcelos
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | guerrero negro
# Processing Record 2 of Set 4 | pochutla
# Processing Record 3 of Set 4 | manokwari
# Processing Record 4 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | caluquembe
# Processing Record 8 of Set 4 | thinadhoo
# Processing Record 9 of Set 4 | khanpur
# Processing Record 10 of Set 4 | varberg
# Processing Record 11 of Set 4 | sakakah
# Processing Record 12 of Set 4 | masterton
# Processing Record 13 of Set 4 | canandaigua
# Processing Record 14 of Set 4 | lompoc
# Processing Record 15 of Set 4 | pokrovka
# Processing Record 16 of Set 4 | babstovo
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | alta floresta
# Processing Record 19 of Set 4 | golkoy
# Processing Record 20 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 4 | ihosy
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | lawrenceburg
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | mpika
# Processing Record 28 of Set 4 | grand gaube
# Processing Record 29 of Set 4 | russell
# Processing Record 30 of Set 4 | abalak
# Processing Record 31 of Set 4 | igarka
# Processing Record 32 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | kisangani
# Processing Record 35 of Set 4 | middelburg
# Processing Record 36 of Set 4 | siyabuswa
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | manoharpur
# Processing Record 39 of Set 4 | ayan
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 4 | maralal
# Processing Record 43 of Set 4 | khani
# Processing Record 44 of Set 4 | dunda
# Processing Record 45 of Set 4 | dzhebariki-khaya
# Processing Record 46 of Set 4 | rio gallegos
# Processing Record 47 of Set 4 | georgetown
# Processing Record 48 of Set 4 | camacha
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | qaqortoq
# Processing Record 1 of Set 5 | pangody
# Processing Record 2 of Set 5 | bathsheba
# Processing Record 3 of Set 5 | kaitong
# Processing Record 4 of Set 5 | ust-barguzin
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | hasaki
# Processing Record 7 of Set 5 | phangnga
# Processing Record 8 of Set 5 | sovetskiy
# Processing Record 9 of Set 5 | wanaka
# Processing Record 10 of Set 5 | rozivka
# Processing Record 11 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 12 of Set 5 | nanortalik
# Processing Record 13 of Set 5 | corralillo
# Processing Record 14 of Set 5 | waddan
# Processing Record 15 of Set 5 | takab
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | zambezi
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | lusambo
# Processing Record 20 of Set 5 | coihaique
# Processing Record 21 of Set 5 | huangmei
# Processing Record 22 of Set 5 | saint marys
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | vanimo
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | athabasca
# Processing Record 27 of Set 5 | manzhouli
# Processing Record 28 of Set 5 | khuzhir
# Processing Record 29 of Set 5 | mezen
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 5 | araouane
# Processing Record 33 of Set 5 | hobyo
# Processing Record 34 of Set 5 | kavieng
# Processing Record 35 of Set 5 | tigre
# Processing Record 36 of Set 5 | januaria
# Processing Record 37 of Set 5 | lazarev
# Processing Record 38 of Set 5 | shalya
# Processing Record 39 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 5 | quatre cocos
# Processing Record 41 of Set 5 | tazovskiy
# Processing Record 42 of Set 5 | ilanskiy
# Processing Record 43 of Set 5 | takaka
# Processing Record 44 of Set 5 | sao filipe
# Processing Record 45 of Set 5 | alekseyevsk
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | nantucket
# Processing Record 49 of Set 5 | copiapo
# Processing Record 50 of Set 5 | masyaf
# Processing Record 1 of Set 6 | hurghada
# Processing Record 2 of Set 6 | yellowknife
# Processing Record 3 of Set 6 | farim
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 6 | fare
# Processing Record 7 of Set 6 | ancud
# Processing Record 8 of Set 6 | vikhorevka
# Processing Record 9 of Set 6 | nakamura
# Processing Record 10 of Set 6 | mogadishu
# Processing Record 11 of Set 6 | cap malheureux
# Processing Record 12 of Set 6 | sabang
# Processing Record 13 of Set 6 | kalabo
# Processing Record 14 of Set 6 | papagaios
# Processing Record 15 of Set 6 | te anau
# Processing Record 16 of Set 6 | mnogovershinnyy
# Processing Record 17 of Set 6 | lucapa
# Processing Record 18 of Set 6 | toba
# Processing Record 19 of Set 6 | bismarck
# Processing Record 20 of Set 6 | axim
# Processing Record 21 of Set 6 | wa
# City not found. Skipping...
# Processing Record 22 of Set 6 | qianguo
# Processing Record 23 of Set 6 | tasiilaq
# Processing Record 24 of Set 6 | saint-augustin
# Processing Record 25 of Set 6 | norman wells
# Processing Record 26 of Set 6 | jalu
# Processing Record 27 of Set 6 | cefalu
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | kaitangata
# Processing Record 30 of Set 6 | chesma
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | jiangyou
# Processing Record 33 of Set 6 | bodden town
# Processing Record 34 of Set 6 | vicosa
# Processing Record 35 of Set 6 | itaituba
# Processing Record 36 of Set 6 | bara
# Processing Record 37 of Set 6 | maceio
# Processing Record 38 of Set 6 | zhadovka
# Processing Record 39 of Set 6 | oytal
# Processing Record 40 of Set 6 | kars
# Processing Record 41 of Set 6 | mao
# Processing Record 42 of Set 6 | mizdah
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | quelimane
# Processing Record 45 of Set 6 | roma
# Processing Record 46 of Set 6 | lakhipur
# Processing Record 47 of Set 6 | east london
# Processing Record 48 of Set 6 | guicheng
# City not found. Skipping...
# Processing Record 49 of Set 6 | sao felix do xingu
# Processing Record 50 of Set 6 | vigrestad
# Processing Record 1 of Set 7 | saint-francois
# Processing Record 2 of Set 7 | garden city
# Processing Record 3 of Set 7 | flinders
# Processing Record 4 of Set 7 | najran
# Processing Record 5 of Set 7 | chimbote
# Processing Record 6 of Set 7 | ingham
# Processing Record 7 of Set 7 | pabna
# Processing Record 8 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | san cristobal
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | cortland
# Processing Record 13 of Set 7 | svetlyy
# Processing Record 14 of Set 7 | aykhal
# Processing Record 15 of Set 7 | shitanjing
# Processing Record 16 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 7 | sinnai
# Processing Record 18 of Set 7 | rawson
# Processing Record 19 of Set 7 | minsk
# Processing Record 20 of Set 7 | khandyga
# Processing Record 21 of Set 7 | gidole
# Processing Record 22 of Set 7 | bukachacha
# Processing Record 23 of Set 7 | porto belo
# Processing Record 24 of Set 7 | puerto leguizamo
# Processing Record 25 of Set 7 | puerto escondido
# Processing Record 26 of Set 7 | kendari
# Processing Record 27 of Set 7 | bundaberg
# Processing Record 28 of Set 7 | bandarbeyla
# Processing Record 29 of Set 7 | kawalu
# Processing Record 30 of Set 7 | pangnirtung
# Processing Record 31 of Set 7 | menongue
# Processing Record 32 of Set 7 | poso
# Processing Record 33 of Set 7 | chapais
# Processing Record 34 of Set 7 | rebrikha
# Processing Record 35 of Set 7 | bonavista
# Processing Record 36 of Set 7 | utete
# Processing Record 37 of Set 7 | pisco
# Processing Record 38 of Set 7 | touros
# Processing Record 39 of Set 7 | audru
# Processing Record 40 of Set 7 | ramshir
# Processing Record 41 of Set 7 | grindavik
# Processing Record 42 of Set 7 | saint-louis
# Processing Record 43 of Set 7 | flin flon
# Processing Record 44 of Set 7 | tibati
# Processing Record 45 of Set 7 | lerwick
# Processing Record 46 of Set 7 | nemuro
# Processing Record 47 of Set 7 | masallatah
# Processing Record 48 of Set 7 | tautira
# Processing Record 49 of Set 7 | abha
# Processing Record 50 of Set 7 | nome
# Processing Record 1 of Set 8 | akdepe
# Processing Record 2 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 8 | zyryanka
# Processing Record 4 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 8 | okha
# Processing Record 6 of Set 8 | bowen
# Processing Record 7 of Set 8 | rocha
# Processing Record 8 of Set 8 | zarand
# Processing Record 9 of Set 8 | dalaba
# Processing Record 10 of Set 8 | maldonado
# Processing Record 11 of Set 8 | kampot
# Processing Record 12 of Set 8 | millville
# Processing Record 13 of Set 8 | monrovia
# Processing Record 14 of Set 8 | kerrobert
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | asbury park
# Processing Record 17 of Set 8 | maneromango
# Processing Record 18 of Set 8 | michelstadt
# Processing Record 19 of Set 8 | saurimo
# Processing Record 20 of Set 8 | malanje
# Processing Record 21 of Set 8 | dutlwe
# Processing Record 22 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 23 of Set 8 | bandar
# Processing Record 24 of Set 8 | angoram
# Processing Record 25 of Set 8 | pontalina
# Processing Record 26 of Set 8 | bozoum
# Processing Record 27 of Set 8 | los llanos de aridane
# Processing Record 28 of Set 8 | salta
# Processing Record 29 of Set 8 | gat
# Processing Record 30 of Set 8 | yulara
# Processing Record 31 of Set 8 | gacko
# Processing Record 32 of Set 8 | batman
# Processing Record 33 of Set 8 | teahupoo
# Processing Record 34 of Set 8 | troitskoye
# Processing Record 35 of Set 8 | puerto colombia
# Processing Record 36 of Set 8 | ningxiang
# Processing Record 37 of Set 8 | aktau
# Processing Record 38 of Set 8 | purranque
# Processing Record 39 of Set 8 | sinnamary
# Processing Record 40 of Set 8 | emerald
# Processing Record 41 of Set 8 | eirunepe
# Processing Record 42 of Set 8 | wattegama
# Processing Record 43 of Set 8 | ouallam
# Processing Record 44 of Set 8 | hami
# Processing Record 45 of Set 8 | kodiak
# Processing Record 46 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 8 | kashi
# Processing Record 48 of Set 8 | faya
# Processing Record 49 of Set 8 | amahai
# Processing Record 50 of Set 8 | talnakh
# Processing Record 1 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 9 | khasan
# Processing Record 3 of Set 9 | piltene
# Processing Record 4 of Set 9 | davila
# Processing Record 5 of Set 9 | ostrovnoy
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | tame
# Processing Record 8 of Set 9 | pevek
# Processing Record 9 of Set 9 | havre-saint-pierre
# Processing Record 10 of Set 9 | ascension
# Processing Record 11 of Set 9 | energeticheskiy
# Processing Record 12 of Set 9 | srednekolymsk
# Processing Record 13 of Set 9 | novikovo
# Processing Record 14 of Set 9 | kolimvari
# City not found. Skipping...
# Processing Record 15 of Set 9 | balkhash
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | sampit
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 21 of Set 9 | bonfim
# Processing Record 22 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 25 of Set 9 | rincon
# Processing Record 26 of Set 9 | honningsvag
# Processing Record 27 of Set 9 | vostok
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | le port
# Processing Record 30 of Set 9 | starkville
# Processing Record 31 of Set 9 | korogwe
# City not found. Skipping...
# Processing Record 32 of Set 9 | brooks
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | himora
# City not found. Skipping...
# Processing Record 35 of Set 9 | guilin
# Processing Record 36 of Set 9 | plettenberg bay
# Processing Record 37 of Set 9 | roald
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | rovaniemi
# Processing Record 40 of Set 9 | dunedin
# Processing Record 41 of Set 9 | hammerfest
# Processing Record 42 of Set 9 | airai
# Processing Record 43 of Set 9 | portland
# Processing Record 44 of Set 9 | xichang
# Processing Record 45 of Set 9 | oranjemund
# Processing Record 46 of Set 9 | forestville
# Processing Record 47 of Set 9 | namatanai
# Processing Record 48 of Set 9 | ponta delgada
# Processing Record 49 of Set 9 | mosetse
# Processing Record 50 of Set 9 | aporawan
# City not found. Skipping...
# Processing Record 1 of Set 10 | acapulco
# Processing Record 2 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 10 | santa cruz
# Processing Record 4 of Set 10 | malpe
# Processing Record 5 of Set 10 | sao joao da barra
# Processing Record 6 of Set 10 | goya
# Processing Record 7 of Set 10 | vila franca do campo
# Processing Record 8 of Set 10 | mehamn
# Processing Record 9 of Set 10 | ligayan
# Processing Record 10 of Set 10 | belaya gora
# Processing Record 11 of Set 10 | lukaya
# Processing Record 12 of Set 10 | gillette
# Processing Record 13 of Set 10 | utiel
# Processing Record 14 of Set 10 | asau
# Processing Record 15 of Set 10 | vardo
# Processing Record 16 of Set 10 | isoka
# Processing Record 17 of Set 10 | susanville
# Processing Record 18 of Set 10 | nara
# Processing Record 19 of Set 10 | bengkulu
# Processing Record 20 of Set 10 | avera
# Processing Record 21 of Set 10 | alice springs
# Processing Record 22 of Set 10 | kostek
# Processing Record 23 of Set 10 | trinidad
# Processing Record 24 of Set 10 | tessalit
# Processing Record 25 of Set 10 | daru
# Processing Record 26 of Set 10 | ambilobe
# Processing Record 27 of Set 10 | dudinka
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | lincoln
# Processing Record 30 of Set 10 | ribeira brava
# Processing Record 31 of Set 10 | godhra
# Processing Record 32 of Set 10 | skelleftea
# Processing Record 33 of Set 10 | wenling
# Processing Record 34 of Set 10 | taga
# Processing Record 35 of Set 10 | santa rosa
# Processing Record 36 of Set 10 | camana
# Processing Record 37 of Set 10 | panaba
# Processing Record 38 of Set 10 | sakaiminato
# Processing Record 39 of Set 10 | ulladulla
# Processing Record 40 of Set 10 | birjand
# Processing Record 41 of Set 10 | palmer
# Processing Record 42 of Set 10 | baikunthpur
# Processing Record 43 of Set 10 | gorontalo
# Processing Record 44 of Set 10 | elizabeth city
# Processing Record 45 of Set 10 | vestmannaeyjar
# Processing Record 46 of Set 10 | pacifica
# Processing Record 47 of Set 10 | ayagoz
# Processing Record 48 of Set 10 | zemio
# Processing Record 49 of Set 10 | huejuquilla el alto
# Processing Record 50 of Set 10 | severo-kurilsk
# Processing Record 1 of Set 11 | oktyabrskiy
# Processing Record 2 of Set 11 | terrace bay
# Processing Record 3 of Set 11 | san jose
# Processing Record 4 of Set 11 | cravo norte
# Processing Record 5 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 11 | presidente epitacio
# Processing Record 7 of Set 11 | provideniya
# Processing Record 8 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 11 | asyut
# Processing Record 10 of Set 11 | port macquarie
# Processing Record 11 of Set 11 | bima
# Processing Record 12 of Set 11 | weligama
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | aguimes
# Processing Record 15 of Set 11 | champerico
# Processing Record 16 of Set 11 | honiara
# Processing Record 17 of Set 11 | boyolangu
# Processing Record 18 of Set 11 | pahrump
# Processing Record 19 of Set 11 | bosaso
# Processing Record 20 of Set 11 | klaksvik
# Processing Record 21 of Set 11 | kerema
# Processing Record 22 of Set 11 | souillac
# Processing Record 23 of Set 11 | wyndham
# Processing Record 24 of Set 11 | at-bashi
# Processing Record 25 of Set 11 | surgut
# Processing Record 26 of Set 11 | kalianget
# Processing Record 27 of Set 11 | piedras amarillas
# City not found. Skipping...
# Processing Record 28 of Set 11 | kirakira
# Processing Record 29 of Set 11 | elwood
# Processing Record 30 of Set 11 | biak
# Processing Record 31 of Set 11 | hovd
# Processing Record 32 of Set 11 | rongcheng
# Processing Record 33 of Set 11 | manono
# Processing Record 34 of Set 11 | seymchan
# Processing Record 35 of Set 11 | codrington
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | kankon
# Processing Record 38 of Set 11 | olenegorsk
# Processing Record 39 of Set 11 | alofi
# Processing Record 40 of Set 11 | fairbanks
# Processing Record 41 of Set 11 | vilhena
# Processing Record 42 of Set 11 | kindu
# Processing Record 43 of Set 11 | inta
# Processing Record 44 of Set 11 | linares
# Processing Record 45 of Set 11 | kuytun
# Processing Record 46 of Set 11 | uruguaiana
# Processing Record 47 of Set 11 | sibolga
# Processing Record 48 of Set 11 | cayenne
# Processing Record 49 of Set 11 | medea
# Processing Record 50 of Set 11 | antsohihy
# Processing Record 1 of Set 12 | fukue
# Processing Record 2 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 12 | cartagena
# Processing Record 4 of Set 12 | marrakesh
# Processing Record 5 of Set 12 | tura
# Processing Record 6 of Set 12 | bauchi
# Processing Record 7 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 12 | charters towers
# Processing Record 9 of Set 12 | marzuq
# Processing Record 10 of Set 12 | la ronge
# Processing Record 11 of Set 12 | belyy yar
# Processing Record 12 of Set 12 | lazaro cardenas
# Processing Record 13 of Set 12 | omboue
# Processing Record 14 of Set 12 | bertinoro
# Processing Record 15 of Set 12 | isangel
# Processing Record 16 of Set 12 | camopi
# Processing Record 17 of Set 12 | sao pedro do sul
# Processing Record 18 of Set 12 | duvan
# Processing Record 19 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 20 of Set 12 | cedar city
# Processing Record 21 of Set 12 | slavsk
# Processing Record 22 of Set 12 | dali
# Processing Record 23 of Set 12 | yaan
# Processing Record 24 of Set 12 | chitose
# Processing Record 25 of Set 12 | laguna
# Processing Record 26 of Set 12 | belogradcik
# City not found. Skipping...
# Processing Record 27 of Set 12 | malazgirt
# Processing Record 28 of Set 12 | broken hill
# Processing Record 29 of Set 12 | korla
# Processing Record 30 of Set 12 | san francisco
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | aquiraz
# Processing Record 33 of Set 12 | the pas
# Processing Record 34 of Set 12 | solnechnyy
# Processing Record 35 of Set 12 | constitucion
# Processing Record 36 of Set 12 | capela
# Processing Record 37 of Set 12 | nizwa
# Processing Record 38 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 12 | san patricio
# Processing Record 40 of Set 12 | jieshi
# Processing Record 41 of Set 12 | ljubinje
# Processing Record 42 of Set 12 | sortland
# Processing Record 43 of Set 12 | zinder
# Processing Record 44 of Set 12 | yarada
# Processing Record 45 of Set 12 | totness
# Processing Record 46 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 12 | brae
# Processing Record 48 of Set 12 | banepa
# Processing Record 49 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 50 of Set 12 | aljezur
# Processing Record 1 of Set 13 | ulagan
# Processing Record 2 of Set 13 | atar
# Processing Record 3 of Set 13 | mount pleasant
# Processing Record 4 of Set 13 | mount isa
# Processing Record 5 of Set 13 | molo
# Processing Record 6 of Set 13 | nouadhibou
# Processing Record 7 of Set 13 | vedaranniyam
# City not found. Skipping...
# Processing Record 8 of Set 13 | micheweni
# Processing Record 9 of Set 13 | ozinki
# Processing Record 10 of Set 13 | ballina
# Processing Record 11 of Set 13 | westport
# Processing Record 12 of Set 13 | nelson bay
# Processing Record 13 of Set 13 | nizhnevartovsk
# Processing Record 14 of Set 13 | pundaguitan
# Processing Record 15 of Set 13 | ormara
# Processing Record 16 of Set 13 | prince rupert
# Processing Record 17 of Set 13 | sistranda
# Processing Record 18 of Set 13 | jahanabad
# Processing Record 19 of Set 13 | dunning
# Processing Record 20 of Set 13 | morro bay
# Processing Record 21 of Set 13 | peterhead
# Processing Record 22 of Set 13 | llangefni
# Processing Record 23 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 24 of Set 13 | strezhevoy
# Processing Record 25 of Set 13 | mananjary
# Processing Record 26 of Set 13 | yomou
# Processing Record 27 of Set 13 | billings
# Processing Record 28 of Set 13 | maymanak
# City not found. Skipping...
# Processing Record 29 of Set 13 | acuexcomac
# Processing Record 30 of Set 13 | ankpa
# Processing Record 31 of Set 13 | santa maria del oro
# Processing Record 32 of Set 13 | taltal
# Processing Record 33 of Set 13 | clarksdale
# Processing Record 34 of Set 13 | urumqi
# Processing Record 35 of Set 13 | klamath falls
# Processing Record 36 of Set 13 | manali
# Processing Record 37 of Set 13 | normandin
# Processing Record 38 of Set 13 | digha
# Processing Record 39 of Set 13 | gobabis
# Processing Record 40 of Set 13 | vila
# Processing Record 41 of Set 13 | gold coast
# Processing Record 42 of Set 13 | blackwater
# Processing Record 43 of Set 13 | huntingdon
# Processing Record 44 of Set 13 | kot addu
# Processing Record 45 of Set 13 | san pedro
# Processing Record 46 of Set 13 | qiongshan
# Processing Record 47 of Set 13 | zeya
# Processing Record 48 of Set 13 | kiama
# Processing Record 49 of Set 13 | prado
# Processing Record 50 of Set 13 | catuday
# Processing Record 1 of Set 14 | tevriz
# Processing Record 2 of Set 14 | praia
# Processing Record 3 of Set 14 | vila do maio
# Processing Record 4 of Set 14 | esmeraldas
# Processing Record 5 of Set 14 | meulaboh
# Processing Record 6 of Set 14 | katobu
# Processing Record 7 of Set 14 | oga
# Processing Record 8 of Set 14 | priladozhskiy
# Processing Record 9 of Set 14 | mosquera
# Processing Record 10 of Set 14 | aksarka
# Processing Record 11 of Set 14 | bac lieu
# Processing Record 12 of Set 14 | mandalgovi
# Processing Record 13 of Set 14 | sur
# Processing Record 14 of Set 14 | ahuimanu
# Processing Record 15 of Set 14 | wuwei
# Processing Record 16 of Set 14 | nyahururu
# Processing Record 17 of Set 14 | vitim
# Processing Record 18 of Set 14 | mayumba
# Processing Record 19 of Set 14 | cap-aux-meules
# Processing Record 20 of Set 14 | juneau
# Processing Record 21 of Set 14 | minab
# Processing Record 22 of Set 14 | west bay
# Processing Record 23 of Set 14 | porto walter
# Processing Record 24 of Set 14 | luwuk
# Processing Record 25 of Set 14 | havoysund
# Processing Record 26 of Set 14 | mutoko
# Processing Record 27 of Set 14 | bahir dar
# Processing Record 28 of Set 14 | terra rica
# Processing Record 29 of Set 14 | irbit
# Processing Record 30 of Set 14 | pinotepa nacional
# Processing Record 31 of Set 14 | luang prabang
# Processing Record 32 of Set 14 | culebra
# Processing Record 33 of Set 14 | itarema
# Processing Record 34 of Set 14 | puri
# Processing Record 35 of Set 14 | panlaitan
# Processing Record 36 of Set 14 | suez
# Processing Record 37 of Set 14 | umm kaddadah
# Processing Record 38 of Set 14 | pafos
# Processing Record 39 of Set 14 | aasiaat
# Processing Record 40 of Set 14 | sept-iles
# Processing Record 41 of Set 14 | chunskiy
# Processing Record 42 of Set 14 | ahome
# Processing Record 43 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 14 | bonthe
# Processing Record 45 of Set 14 | meghri
# Processing Record 46 of Set 14 | alghero
# Processing Record 47 of Set 14 | juba
# Processing Record 48 of Set 14 | shakawe
# Processing Record 49 of Set 14 | belousovka
# Processing Record 50 of Set 14 | hanzhong
# Processing Record 1 of Set 15 | sarangani
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | chadiza
# Processing Record 4 of Set 15 | burla
# Processing Record 5 of Set 15 | purpe
# Processing Record 6 of Set 15 | datong
# Processing Record 7 of Set 15 | nizhniy kuranakh
# Processing Record 8 of Set 15 | iquitos
# Processing Record 9 of Set 15 | richards bay
# Processing Record 10 of Set 15 | sorland
# Processing Record 11 of Set 15 | polignano a mare
# Processing Record 12 of Set 15 | celestun
# Processing Record 13 of Set 15 | inuvik
# Processing Record 14 of Set 15 | paamiut
# Processing Record 15 of Set 15 | canakkale
# Processing Record 16 of Set 15 | sumbe
# Processing Record 17 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 15 | necochea
# Processing Record 19 of Set 15 | gongzhuling
# Processing Record 20 of Set 15 | taoudenni
# Processing Record 21 of Set 15 | mildura
# Processing Record 22 of Set 15 | pemangkat
# Processing Record 23 of Set 15 | guarda
# Processing Record 24 of Set 15 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 15 | byron bay
# Processing Record 26 of Set 15 | boston
# Processing Record 27 of Set 15 | mackay
# Processing Record 28 of Set 15 | khorramshahr
# Processing Record 29 of Set 15 | bati
# Processing Record 30 of Set 15 | porto novo
# Processing Record 31 of Set 15 | ugoofaaru
# Processing Record 32 of Set 15 | gao
# Processing Record 33 of Set 15 | san bernardo
# Processing Record 34 of Set 15 | cullman
# Processing Record 35 of Set 15 | kupang
# Processing Record 36 of Set 15 | salinas
# Processing Record 37 of Set 15 | riyadh
# Processing Record 38 of Set 15 | aginskoye
# Processing Record 39 of Set 15 | pimenta bueno
# Processing Record 40 of Set 15 | george
# Processing Record 41 of Set 15 | kultayevo
# Processing Record 42 of Set 15 | buraydah
# Processing Record 43 of Set 15 | hamilton
# Processing Record 44 of Set 15 | agadez
# Processing Record 45 of Set 15 | platanos
# Processing Record 46 of Set 15 | thunder bay
# Processing Record 47 of Set 15 | tiznit
# Processing Record 48 of Set 15 | chipinge
# Processing Record 49 of Set 15 | villanueva de cordoba
# Processing Record 50 of Set 15 | savonlinna
# Processing Record 1 of Set 16 | tucuman
# Processing Record 2 of Set 16 | kibala
# Processing Record 3 of Set 16 | wadena
# Processing Record 4 of Set 16 | halle
# Processing Record 5 of Set 16 | tefe
# Processing Record 6 of Set 16 | noumea
# Processing Record 7 of Set 16 | senmonorom
# City not found. Skipping...
# Processing Record 8 of Set 16 | falaleu
# City not found. Skipping...
# Processing Record 9 of Set 16 | kapoeta
# Processing Record 10 of Set 16 | seit
# City not found. Skipping...
# Processing Record 11 of Set 16 | rorvik
# Processing Record 12 of Set 16 | constantine
# Processing Record 13 of Set 16 | pierre
# Processing Record 14 of Set 16 | peniche
# Processing Record 15 of Set 16 | maniitsoq
# Processing Record 16 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 16 | cassia
# Processing Record 18 of Set 16 | doha
# Processing Record 19 of Set 16 | anjozorobe
# Processing Record 20 of Set 16 | luancheng
# Processing Record 21 of Set 16 | beloha
# Processing Record 22 of Set 16 | ulaangom
# Processing Record 23 of Set 16 | cozumel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kieta      PG  -6.2167  155.6333     84.04        72          75
# 1       Jamestown      US  42.0970  -79.2353     35.19        90           1
# 2          Avarua      CK -21.2078 -159.7750     82.45        78          23
# 3          Hirara      JP  24.8000  125.2833     75.47        78          75
# 4  Cabo San Lucas      MX  22.8909 -109.9124     88.61        39          90
# 5   Saint Anthony      US  45.0205  -93.2180     47.89        79           1
# 6   Leningradskiy      RU  69.3833  178.4167     -2.52        95          56
# 7           Bluff      NZ -46.6000  168.3333     54.48        65          77
# 8    Kruisfontein      ZA -34.0033   24.7314     62.89        89         100
# 9         Malkara      TR  40.8900   26.9011     45.50        70         100
#
#    Wind Speed Current Description
# 0        2.98          light rain
# 1        0.00           clear sky
# 2       14.97          few clouds
# 3       12.66       broken clouds
# 4        1.99     overcast clouds
# 5        1.99           clear sky
# 6        9.60       broken clouds
# 7       21.61       broken clouds
# 8       10.04     overcast clouds
# 9       12.06     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the Weather_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
